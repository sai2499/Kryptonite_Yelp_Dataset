# %%
import psycopg2
  
# establishing the connection
conn = psycopg2.connect(
   database="Yelp",
    user='postgres',
    password='root',
    host='localhost',
    port= '5432'
)
  
# Creating a cursor object using the cursor()
# method
cursor = conn.cursor()
  

# Display whole table
cursor.execute("SELECT * FROM yelp_user")
rows = cursor.fetchall()

user_id = []
friends_id = []

dict_values = {}

for row in rows:
   dict_values[row[0]] = row[4]
  
# Commit your changes in the database
conn.commit()
  
# #Closing the connection

# %%
print(dict_values)

# %%
for key, value in dict_values.items():
    for  i in range(0, len(value)):
        user_id.append(key)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In [6], line 3
#       1 for key, value in dict_values.items():
#       2     for  i in range(0, len(value)):
# ----> 3         user_id.append(key)
#
# MemoryError:

# %%
for key, value in dict_values.items():
    for i in value:
        friends_id.append(i)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In [4], line 3
#       1 for key, value in dict_values.items():
#       2     for i in value:
# ----> 3         friends_id.append(i)
#
# MemoryError:

# %%
dict_values
# Out:
# ['Dentists',
#  'General Dentistry',
#  'Health & Medical',
#  'Oral Surgeons',
#  'Cosmetic Dentists',
#  'Orthodontists',
#  'Hair Stylists',
#  'Hair Salons',
#  "Men's Hair Salons",
#  'Blow Dry/Out Services',
#  'Hair Extensions',
#  'Beauty & Spas',
#  'Departments of Motor Vehicles',
#  'Public Services & Government',
#  'Sporting Goods',
#  'Shopping',
#  'American (New)',
#  'Nightlife',
#  'Bars',
#  'Sandwiches',
#  'American (Traditional)',
#  'Burgers',
#  'Restaurants',
#  'Italian',
#  'Restaurants',
#  'Real Estate Services',
#  'Real Estate',
#  'Home Services',
#  'Property Management',
#  'Shopping',
#  'Sporting Goods',
#  'Coffee & Tea',
#  'Ice Cream & Frozen Yogurt',
#  'Food',
#  'Automotive',
#  'Auto Detailing',
#  'Breakfast & Brunch',
#  'Gluten-Free',
#  'Coffee & Tea',
#  'Food',
#  'Restaurants',
#  'Sandwiches',
#  'Local Services',
#  'Self Storage',
#  'Bakeries',
#  'Bagels',
#  'Food',
#  'General Dentistry',
#  'Dentists',
#  'Endodontists',
# ...

# %%
print(len(business_id), "\t", len(categories))
# Out:
# 668027 	 668027

# %%
conn = psycopg2.connect(
   database="Yelp",
    user='postgres',
    password='root',
    host='localhost',
    port= '5432'
)
  
# Creating a cursor object using the cursor()
# method
cursor = conn.cursor()
create_statement = "CREATE TABLE yelp_categories(business_id varchar(50), categories char(50))"
cursor.execute(create_statement)
print("Table created successfully")

conn.commit()
conn.close()
# Out:
# Table created successfully

# %%
conn = psycopg2.connect(
   database="Yelp",
    user='postgres',
    password='root',
    host='localhost',
    port= '5432'
)
  
# Creating a cursor object using the cursor()
# method
cursor = conn.cursor()
insert_statement = "INSERT INTO Categories values (%s, %s);"
final_list = []
for i, j in zip(business_id, categories):
    final_list.append((i,j))

cursor.executemany(insert_statement, final_list)

conn.commit()
conn.close()
